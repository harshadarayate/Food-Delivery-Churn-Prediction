# %% [markdown]
# # DATA CREATION

# %%
# !pip install faker  # for generating fake data
# Out:
# Requirement already satisfied: faker in /home/mystique/miniconda3/lib/python3.12/site-packages (37.3.0)
# Requirement already satisfied: tzdata in /home/mystique/miniconda3/lib/python3.12/site-packages (from faker) (2025.1)

# %%
import pandas as pd
import numpy as np
from faker import Faker
import random

fake = Faker()

def generate_food_delivery_churn_dataset(n=500):
    data = []
    for i in range(101, 101 + n):
        customer_id = i
        orders_last_3_months = np.random.poisson(lam=5)
        avg_order_value = f"₹{random.randint(150, 600)}"
        app_opens_per_week = np.random.randint(1, 15)
        complaints = np.random.poisson(lam=1)
        used_offers = random.choice(["Yes", "No"])
        last_order_date = fake.date_between(start_date='-1y', end_date='today')
        membership = random.choice(["Yes", "No"])
        is_churned = int((orders_last_3_months <= 2 and app_opens_per_week <= 3) or complaints >= 3)

        data.append([
            customer_id,
            orders_last_3_months,
            avg_order_value,
            app_opens_per_week,
            complaints,
            used_offers,
            last_order_date,
            membership,
            is_churned
        ])
    
    columns = [
        "Customer_ID", "Orders_Last_3_Months", "Avg_Order_Value", "App_Opens_Per_Week",
        "Complaints", "Used_Offers", "Last_Order_Date", "Membership", "Is_Churned"
    ]
    
    return pd.DataFrame(data, columns=columns)

# Create and display the dataset
churn_df = generate_food_delivery_churn_dataset(500)

# %%
churn_df.to_csv('./food_delivery_churn_dataset.csv', index=False)

# %%
churn_df.head(50)
# Out:
#     Customer_ID  Orders_Last_3_Months Avg_Order_Value  App_Opens_Per_Week  \
# 0           101                     6            ₹432                   7
# 1           102                     1            ₹532                  13
# 2           103                     8            ₹433                  14
# 3           104                     3            ₹499                   4
# 4           105                     9            ₹260                  14
# 5           106                     4            ₹425                   1
# 6           107                     7            ₹345                   5
# 7           108                     7            ₹430                  12
# 8           109                     3            ₹405                   1
# 9           110                     4            ₹546                   4
# 10          111                     7            ₹168                  10
# 11          112                     5            ₹554                  10
# 12          113                     2            ₹408                  12
# 13          114                     3            ₹242                   6
# 14          115                     3            ₹373                   3
# 15          116                     1            ₹463                   7
# 16          117                     7            ₹596                  14
# 17          118                     8            ₹300                   6
# 18          119                     2            ₹440                   3
# 19          120                     7            ₹600                  11
# 20          121                     6            ₹569                  13
# 21          122                     6            ₹338                   7
# 22          123                     8            ₹338                   5
# 23          124                     6            ₹438                   9
# 24          125                     2            ₹464                  10
# 25          126                     4            ₹499                  14
# 26          127                     2            ₹453                   1
# 27          128                     4            ₹434                   5
# 28          129                     1            ₹480                   4
# 29          130                     3            ₹448                   9
# 30          131                     4            ₹214                  12
# 31          132                     4            ₹198                  13
# 32          133                     3            ₹584                   9
# 33          134                     3            ₹301                  13
